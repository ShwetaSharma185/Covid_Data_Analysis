# %% [markdown]
# **Folium** is built on the data wrangling strengths of the Python ecosystem and the mapping strengths of the Leaflet.js (JavaScript) library. Simply, manipulate your data in Python, then visualize it on a leaflet map via Folium. Folium makes it easy to visualize data that’s been manipulated in Python, on an interactive Leaflet map.
#
# Python provides folium as one of the powerful library

# %%
import folium
import pandas as pd
import numpy as np
df_usa=pd.DataFrame(pd.read_csv('usa_county_wise.csv'))
df_usa.head()
# Out:
#           UID iso2 iso3  ...        Date  Confirmed Deaths
# 0        16.0   AS  ASM  ...  07-12-2020        0.0    0.0
# 1       316.0   GU  GUM  ...  07-12-2020      310.0    5.0
# 2       580.0   MP  MNP  ...  07-12-2020       33.0    2.0
# 3  63072001.0   PR  PRI  ...  07-12-2020       63.0    0.0
# 4  63072003.0   PR  PRI  ...  07-12-2020       54.0    0.0
#
# [5 rows x 14 columns]

# %%
# get first 150 records
limit=150
df_usa=df_usa.iloc[0:limit,:]
df_usa.head()
# Out:
#           UID iso2 iso3  ...        Date  Confirmed Deaths
# 0        16.0   AS  ASM  ...  07-12-2020        0.0    0.0
# 1       316.0   GU  GUM  ...  07-12-2020      310.0    5.0
# 2       580.0   MP  MNP  ...  07-12-2020       33.0    2.0
# 3  63072001.0   PR  PRI  ...  07-12-2020       63.0    0.0
# 4  63072003.0   PR  PRI  ...  07-12-2020       54.0    0.0
#
# [5 rows x 14 columns]

# %%
print('plot any single data')
locationx=df_usa.head(1).Lat[0]
locationy=df_usa.head(1).Long_[0]
m=folium.Map(location=[locationx,locationy],tiles='Stamen Terrain',zoom_start=15)
m
# Out:
# plot any single data
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print(' Add all locations ')
incidents=folium.map.FeatureGroup()

#add all maps
for lat,long in zip(df_usa.Lat,df_usa.Long_):
    
    incidents.add_child(folium.CircleMarker(location=[lat,long],radius=5,color='red',fill='True',fill_color='blue',transparency=0.6))

# add it to map
m.add_child(incidents)
m
# Out:
#  Add all locations
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print(' Add all locations with markers')
incidents=folium.map.FeatureGroup()

#add all maps
for long,lat,confirmed in zip(df_usa.Long_,df_usa.Lat,df_usa.Confirmed):
    covid=folium.Marker(location=[lat,long],popup=str(confirmed))
    
    incidents.add_child(covid)
# add it to map
m.add_child(incidents)
m
# Out:
#  Add all locations with markers
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Folium maps are interactive, they contain markers with popups that can be clustered in areas with a high density of points, you can use layers and pick different source maps. And it’s all pretty easy to code:
#
# Using MarkerClustering you can easily cluster areas and get proper view
